# %%
import json
import pandas as pd

path = '/home/codeforces_sft/eval_outputs/base_model/grader_logs.json'
with open(path, 'r') as f:
    grader_logs = json.load(f)

# %%
for problem_id in grader_logs:

    print(problem_id, grader_logs[problem_id]['ratings'])
    status_accept = []
    status_reject = []
    attempts = [k for k in grader_logs[problem_id] if k.startswith('attempt_')]
    attempts.sort(key=lambda x: int(x.split('_')[1]))
    accept_row = [grader_logs[problem_id][a].get('accepted') for a in attempts]
    reason_row = [grader_logs[problem_id][a].get('failure_reasons', '') for a in attempts]
    df = pd.DataFrame([accept_row, reason_row], index=['Accepted', 'Failure Reasons'], columns=attempts)
    display(df)
# Out:
# 2063/A 800
#                 attempt_0 attempt_1 attempt_2 attempt_3 attempt_4 attempt_5  \
# Accepted            False     False     False     False     False     False
# Failure Reasons       TLE       TLE       TLE       TLE       TLE       TLE
#
#                 attempt_6 attempt_7
# Accepted            False     False
# Failure Reasons       TLE       TLE
# 2063/B 1100
#                 attempt_0 attempt_1 attempt_2 attempt_3 attempt_4 attempt_5  \
# Accepted            False     False     False     False     False     False
# Failure Reasons        RE        RE        WA        WA        RE        RE
#
#                 attempt_6 attempt_7
# Accepted            False     False
# Failure Reasons        RE        RE
# 2063/C 1600
#                 attempt_0 attempt_1 attempt_2 attempt_3 attempt_4 attempt_5  \
# Accepted            False     False     False     False     False     False
# Failure Reasons        RE        RE        WA        RE        RE        RE
#
# ...
